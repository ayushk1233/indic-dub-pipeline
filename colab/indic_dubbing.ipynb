# %%
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %%
# !git clone https://github.com/ayushk1233/indic-dub-pipeline.git

# %cd indic-dub-pipeline
# Out:
# Cloning into 'indic-dub-pipeline'...
# remote: Enumerating objects: 415, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 415 (delta 51), reused 65 (delta 27), pack-reused 326 (from 1)
# Receiving objects: 100% (415/415), 78.70 KiB | 1.21 MiB/s, done.
# Resolving deltas: 100% (275/275), done.
# /content/indic-dub-pipeline/indic-dub-pipeline

# %%
# !git pull
# !pip install -r colab/requirements.txt
# Out:
# Already up to date.
# ...

# %%
from colab.preflight import PreflightValidator

report = PreflightValidator().run()

print(report)
# Out:
# {'python': '3.11.13', 'platform': 'Linux-6.6.122+-x86_64-with-glibc2.35', 'torch': '2.5.1+cu124', 'cuda': True, 'gpu': 'Tesla T4', 'gpu_memory_gb': 14.56317138671875, 'tts': '0.22.0'}

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5980f614-a799-4c6f-9386-2995b45e8fa9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5980f614-a799-4c6f-9386-2995b45e8fa9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
from pathlib import Path

bundle_dir = Path("/content/tts_bundle")
bundle_dir.mkdir(exist_ok=True)

with zipfile.ZipFile("tts_bundle.zip", "r") as z:
    z.extractall(bundle_dir)

print("Bundle extracted.")
# Out:
# Bundle extracted.

# %%
from pathlib import Path

bundle_dir = Path("/content/tts_bundle")

print(bundle_dir.exists())

for p in bundle_dir.rglob("*"):
    print(p)
# Out:
# True
# /content/tts_bundle/request
# /content/tts_bundle/manifest.json
# /content/tts_bundle/request/synthesis_request.json
# /content/tts_bundle/request/reference.wav

# %%
from pathlib import Path

from colab.xtts_worker import XTTSWorker

worker = XTTSWorker(
    Path("/content/tts_bundle")
)

worker.load_bundle()

print(worker.request.job_id)
print(worker.request.language)
print("Bundle loaded successfully.")
# Out:
# test_mp4_job
# hi
# Bundle loaded successfully.

# %%
from pathlib import Path

from colab.xtts_worker import XTTSWorker

worker = XTTSWorker(Path("/content/tts_bundle"))

worker.load_bundle()

model = worker.load_model()

print(type(model).__name__)
print(worker.model is model)
print("XTTS model initialized.")
# Out:
# Preflight diagnostics: {'python': '3.11.13', 'platform': 'Linux-6.6.122+-x86_64-with-glibc2.35', 'torch': '2.5.1+cu124', 'cuda': True, 'gpu': 'Tesla T4', 'gpu_memory_gb': 14.56317138671875, 'tts': '0.22.0'}
# Loading XTTS-v2...
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
#  | | > y
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2
# 100%|█████████▉| 1.86G/1.87G [00:30<00:00, 39.8MiB/s]
# 100%|██████████| 1.87G/1.87G [00:30<00:00, 61.2MiB/s]
# 4.37kiB [00:00, 17.9kiB/s]
#
# 361kiB [00:00, 1.42MiB/s]
# 100%|██████████| 32.0/32.0 [00:00<00:00, 105iB/s]
#   0%|          | 1.02k/7.75M [00:00<18:40, 6.92kiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
#  > Using model: xtts
# ...

# %%
# !git pull
# Out:
# Already up to date.

# %%
from colab.xtts_worker import XTTSWorker

print(hasattr(XTTSWorker, "compute_speaker_embedding"))
# Out:
# True

# %%
# !git log --oneline -5
# Out:
# b2623b8 (HEAD -> main, origin/main, origin/HEAD) xtts findings
# 40cfea6 Add XTTS inference debugging
# f25d858 Create output directories when loading bundle
# ced4394 Implement XTTS single segment synthesis
# 1274a22 Implement speaker embedding caching

# %%
import importlib
import colab.xtts_worker

importlib.reload(colab.xtts_worker)

from colab.xtts_worker import XTTSWorker

print(hasattr(XTTSWorker, "compute_speaker_embedding"))
# Out:
# True

# %%
from pathlib import Path

ref = Path("/content/tts_bundle/request/reference.wav")

print(ref.exists())
print(ref.stat().st_size)
# Out:
# True
# 783240

# %%
from pathlib import Path
from colab.xtts_worker import XTTSWorker

worker = XTTSWorker(Path("/content/tts_bundle"))

worker.load_bundle()
worker.load_model()

latent, speaker = worker.compute_speaker_embedding()

print(type(latent))
print(type(speaker))
# Out:
# Preflight diagnostics: {'python': '3.11.13', 'platform': 'Linux-6.6.122+-x86_64-with-glibc2.35', 'torch': '2.5.1+cu124', 'cuda': True, 'gpu': 'Tesla T4', 'gpu_memory_gb': 14.56317138671875, 'tts': '0.22.0'}
# Loading XTTS-v2...
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# Computing speaker embeddings...
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
import importlib
import colab.xtts_worker

importlib.reload(colab.xtts_worker)

from colab.xtts_worker import XTTSWorker

# %%
from pathlib import Path
from colab.xtts_worker import XTTSWorker

worker = XTTSWorker(Path("/content/tts_bundle"))

worker.load_bundle()
worker.load_model()
worker.compute_speaker_embedding()

wav_path = worker.synthesize_segment(
    worker.request.segments[0]
)

print(wav_path)
# Out:
# Preflight diagnostics: {'python': '3.11.13', 'platform': 'Linux-6.6.122+-x86_64-with-glibc2.35', 'torch': '2.5.1+cu124', 'cuda': True, 'gpu': 'Tesla T4', 'gpu_memory_gb': 14.56317138671875, 'tts': '0.22.0'}
# Loading XTTS-v2...
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# Computing speaker embeddings...
# Synthesizing segment 0 (chunk 0)...
# Inference output keys: dict_keys(['wav', 'gpt_latents', 'speaker_embedding'])
# wav: shape=(81152,)
# gpt_latents: shape=(1, 73, 1024)
# speaker_embedding: shape=torch.Size([1, 512, 1])
# Generated samples: 81152
# Approx duration: 3.3813333333333335
# /content/tts_bundle/output/chunk_0000.wav

# %%
from pathlib import Path

wav = Path("/content/tts_bundle/output/chunk_0000.wav")

print(wav.exists())
print(wav.stat().st_size)
# Out:
# True
# 162382

# %%
from IPython.display import Audio

Audio("/content/tts_bundle/output/chunk_0000.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import torchaudio

wav, sr = torchaudio.load("/content/tts_bundle/output/chunk_0000.wav")

print("Sample rate:", sr)
print("Shape:", wav.shape)
print("Duration:", wav.shape[-1] / sr)
# Out:
# Sample rate: 24000
# Shape: torch.Size([1, 81152])
# Duration: 3.3813333333333335

# %%
from IPython.display import Audio

Audio("/content/tts_bundle/request/reference.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
